# %%
def multiply(a,b):
    return(a*b)

# %%
def square(x):
    return multiply(x,x)

# %%
print(multiply(3,5))
print(square(3))

# %%
print(multiply(9,7))
print(square(5))

# %%
print(multiply(7,90))
print(square(10))
